# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import pandas as pd

# %%
ruta='C:/Users/Juan Camilo/Desktop/signals.mat'
data=sio.loadmat(ruta)
data_ecg=data['ECG_asRecording'][0]
siz=np.size(data_ecg)
freq=1024
tiempo=siz/freq
t=np.arange(0,tiempo,1/freq)

# %% [markdown]
# ### Cálculo del tiempo
# ### Para calcular el tiempo, primero cargamos de uno de los archivos (en este caso es ECG Recording) el elemento con los datos que necesitamos, el cual está en la primera posición. Luego de cargar el archivo usamos la función size de la librería numpy para saber sus dimenciones. Seguido de esto dividimos dicho valor entre la frecuencia dada (1024 Hz). Con estos datos ya podemos crear un vector tiempo de la forma [Dato_inicial,Dato Final,Step] definiendo el step como 1/Frecuencia.

# %%
ruta='C:/Users/Juan Camilo/Desktop/signals.mat'
data=sio.loadmat(ruta)
ecg=data['ECG_asRecording'][0]
ecg=ecg-np.median(ecg)
filt=data['ECG_filtered'][0]
filt=filt-np.median(filt)
fig,axs = plt.subplots(2)
axs[0].plot(t,ecg, color='k',label='ecg',lw=0.5)
axs[0].grid(True,lw=0.5)
axs[0].legend()
axs[1].plot(t,filt, color='r',label='Filtered',lw=0.5)
axs[1].grid(True,lw=0.5)
axs[1].legend()
plt.show()
print('Valor Máximo ECG: '+str(np.max(ecg)))
print('Valor Mínimo ECG: '+str(np.min(ecg)))
print('Valor Máximo Filtered: '+str(np.max(filt)))
print('Valor Mínimo Filtered: '+str(np.min(filt)))
# Out:
# Valor Máximo ECG: 2315.51220703125
# Valor Mínimo ECG: -929.524658203125
# Valor Máximo Filtered: 2052.404721502409
# Valor Mínimo Filtered: -636.618811062997

# %% [markdown]
# ### Análisis
# ### Podemos apreciar que se atenúo, esto se evidencia en la reducción en los valores de los datos, además de una leve linealización, ya que en la primera gráfica, los datos generan una leve curva incrementando, mientras que en la segunda gráfica se ven más estables respecto al 0.

# %%
inicio_ciclo=0  # Muestra inicial del ciclo
fin_ciclo=900   # Muestra final del ciclo
c_cardiaco = ecg[inicio_ciclo:fin_ciclo]
t2=t[inicio_ciclo:fin_ciclo]
plt.plot(t2,c_cardiaco,color='g')
plt.title('Ciclo Cardiaco (Normal)')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)
plt.show()
prom=np.mean(c_cardiaco)
rms=np.sqrt(np.mean(c_cardiaco**2))
vari=np.var(c_cardiaco)
dev_estandar=np.std(c_cardiaco)
print('Promedio:', prom)
print('Valor RMS:', rms)
print('Varianza:', vari)
print('Desviación Estándar:', dev_estandar)
# Out:
# Promedio: -216.8295144314236
# Valor RMS: 356.5717026089397
# Varianza: 80128.34077287118
# Desviación Estándar: 283.0694981322982

# %% [markdown]
# ### Análisis

# %%
inicio_ciclo=0  # Muestra inicial del ciclo
fin_ciclo=900   # Muestra final del ciclo
c_cardiaco = filt[inicio_ciclo:fin_ciclo]
t2=t[inicio_ciclo:fin_ciclo]
plt.plot(t2,c_cardiaco,color='b')
plt.title('Ciclo Cardiaco (Filtrada)')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)
plt.show()
prom=np.mean(c_cardiaco)
rms=np.sqrt(np.mean(c_cardiaco**2))
vari=np.var(c_cardiaco)
dev_estandar=np.std(c_cardiaco)
print('Promedio:', prom)
print('Valor RMS:', rms)
print('Varianza:', vari)
print('Desviación Estándar:', dev_estandar)
# Out:
# Promedio: 124.03157801627789
# Valor RMS: 328.0268346848767
# Varianza: 92217.77192817138
# Desviación Estándar: 303.67379196791313

# %% [markdown]
# ### Analisis

# %%
inicio_fin=[0,900]   # Muestra
pas_ciclo=np.array([900,900])
num_cic=15
for i in range(num_cic):
    c_cardiaco = filt[inicio_fin[0]:inicio_fin[1]]
    t2=t[inicio_fin[0]:inicio_fin[1]]
    rgb=np.random.rand(1,3)
    plt.plot(t2,c_cardiaco, label=f'Ciclo {i+1}',color=rgb)
    plt.title('Ciclo '+str(i+1))
    plt.grid(True)
    inicio_fin+=pas_ciclo
    prom=np.mean(c_cardiaco)
    rms=np.sqrt(np.mean(c_cardiaco**2))
    vari=np.var(c_cardiaco)
    dev_estandar=np.std(c_cardiaco)
    informacion={'Promedio Ciclo '+str(i+1)+':':prom,'RMS Ciclo '+str(i+1)+':':rms,'Varianza Ciclo '+str(i+1)+':':vari,'Desviacion Estandar Ciclo '+str(i+1)+':':dev_estandar}
    df=pd.DataFrame.from_dict(informacion, orient='index', columns=['Valor'])
    plt.show()
    display(df)
# Out:
#                                      Valor
# Promedio Ciclo 1:               124.031578
# RMS Ciclo 1:                    328.026835
# Varianza Ciclo 1:             92217.771928
# Desviacion Estandar Ciclo 1:    303.673792
#                                       Valor
# Promedio Ciclo 2:                 55.127603
# RMS Ciclo 2:                     328.377388
# Varianza Ciclo 2:             104792.656343
# Desviacion Estandar Ciclo 2:     323.716939
#                                       Valor
# Promedio Ciclo 3:                 59.319997
# RMS Ciclo 3:                     341.691977
# Varianza Ciclo 3:             113234.544776
# Desviacion Estandar Ciclo 3:     336.503410
#                                      Valor
# Promedio Ciclo 4:                38.613655
# RMS Ciclo 4:                    276.784546
# Varianza Ciclo 4:             75118.670535
# Desviacion Estandar Ciclo 4:    274.077855
#                                      Valor
# Promedio Ciclo 5:                78.785374
# RMS Ciclo 5:                    295.062826
# Varianza Ciclo 5:             80854.936109
# Desviacion Estandar Ciclo 5:    284.350024
#                                      Valor
# Promedio Ciclo 6:                25.700771
# RMS Ciclo 6:                    290.081629
# Varianza Ciclo 6:             83486.821911
# Desviacion Estandar Ciclo 6:    288.940862
#                                      Valor
# Promedio Ciclo 7:                47.659853
# RMS Ciclo 7:                    267.248742
# Varianza Ciclo 7:             69150.428520
# Desviacion Estandar Ciclo 7:    262.964691
#                                      Valor
# Promedio Ciclo 8:                69.201890
# RMS Ciclo 8:                    290.317748
# Varianza Ciclo 8:             79495.493172
# Desviacion Estandar Ciclo 8:    281.949451
#                                      Valor
# Promedio Ciclo 9:                27.245874
# RMS Ciclo 9:                    278.657579
# Varianza Ciclo 9:             76907.708593
# Desviacion Estandar Ciclo 9:    277.322391
#                                       Valor
# Promedio Ciclo 10:                53.644295
# RMS Ciclo 10:                    272.444021
# Varianza Ciclo 10:             71348.034076
# Desviacion Estandar Ciclo 10:    267.110528
#                                       Valor
# Promedio Ciclo 11:                43.089050
# RMS Ciclo 11:                    279.780891
# Varianza Ciclo 11:             76420.680771
# Desviacion Estandar Ciclo 11:    276.442907
#                                       Valor
# Promedio Ciclo 12:                73.981752
# RMS Ciclo 12:                    300.759813
# Varianza Ciclo 12:             84983.165771
# Desviacion Estandar Ciclo 12:    291.518723
#                                       Valor
# Promedio Ciclo 13:                43.817018
# RMS Ciclo 13:                    296.925825
# Varianza Ciclo 13:             86245.014447
# Desviacion Estandar Ciclo 13:    293.675015
#                                       Valor
# Promedio Ciclo 14:                41.095622
# RMS Ciclo 14:                    278.247008
# Varianza Ciclo 14:             75732.547413
# Desviacion Estandar Ciclo 14:    275.195471
#                                       Valor
# Promedio Ciclo 15:                61.766014
# RMS Ciclo 15:                    290.270545
# Varianza Ciclo 15:             80441.948726
# Desviacion Estandar Ciclo 15:    283.622899

# %% [markdown]
# ### Analisis
# ### No podemos considerar que la señal sea estacionaria debido a que los valores de Media (Promedio) y Varianza oscilan demasiado, si quiera para considerar un pequeño porcentaje de error.
